# %% [markdown]
# ![image.png](attachment:a05bdae9-ccc6-4e88-96ae-bd16376558ba.png)

# %%
print([1,2,3])
# Out:
# [1, 2, 3]

# %%
print([1,2,3])
print([4,5,6])
print([7,8,9])
# Out:
# [1, 2, 3]
# [4, 5, 6]
# [7, 8, 9]

# %%
def display(row1,row2,row3):
    print(row1)
    print(row2)
    print(row3)

# %%
example_row = [1,2,3]

display(example_row,example_row,example_row)
# Out:
# [1, 2, 3]
# [1, 2, 3]
# [1, 2, 3]

# %%
row1 = [' ',' ',' ']
row2 = [' ',' ',' ']
row3 = [' ',' ',' ']

# %%
display(row1,row2,row3)
# Out:
# [' ', ' ', ' ']
# [' ', ' ', ' ']
# [' ', ' ', ' ']

# %%
row2[1] = 'X'

# %%
display(row1,row2,row3)
# Out:
# [' ', ' ', ' ']
# [' ', 'X', ' ']
# [' ', ' ', ' ']

# %%
input("Please Enter a Value : ")
# Out:
# Please Enter a Value :  1
# '1'

# %%
result = input("Please Enter a Value : ")
# Out:
# Please Enter a Value :  2

# %%
result
# Out:
# '2'

# %%
type(result)
# Out:
# str

# %%
result = int(result)

# %%
result
# Out:
# 2

# %%
type(result)
# Out:
# int

# %%
float('3.14')
# Out:
# 3.14

# %%
display(row1,row2,row3)
# Out:
# [' ', ' ', ' ']
# [' ', 'X', ' ']
# [' ', ' ', ' ']

# %%
position_index = int(input("Choose an Index Position : "))
# Out:
# Choose an Index Position :  2

# %%
row2[position_index]
# Out:
# ' '

# %%
def user_choice():
    # Variables
    # Initial 
    choice= 'WRONG'
    acceptable_range = range(0,10)
    within_range = False

    # Two Conditions to check
    # Digit or Within range == False 
    
    while choice.isdigit() == False or within_range == False:
        choice = input("Please Enter a Number (0-10):")

        # Digit Check
        if choice.isdigit() == False:
            print("Sorry, that is not a digit!")
        # Range Check
        if choice.isdigit() == True:
            if int(choice) in acceptable_range:
                within_range = True
            else:
                print("Please Enter a Digit between 0 and 9 inclusive Only")
                within_range = False
    
    return int(choice)

# %%
user_choice()
# Out:
# Please Enter a Number (0-10): nine
# Sorry, that is not a digit!
# Please Enter a Number (0-10): 45
# Please Enter a Digit between 0 and 9 inclusive Only
# Please Enter a Number (0-10): 0
# 0

# %%
game_list = [0,1,2]

# %%
def display_game(game_list):
    print("Here is the Current List : ")
    print(game_list)

# %%
display_game(game_list)
# Out:
# Here is the Current List :
# [0, 1, 2]

# %%
def position_choice():
    choice = 'wrong'

    while choice not in ['0','1','2']:
        choice = input("Pick a position (0,1,2) : ")

        if choice not in ['0','1','2']:
            print("Invalid Choice!")

    return int(choice)

# %%
position_choice()
# Out:
# Pick a position (0,1,2) :  24
# Invalid Choice!
# Pick a position (0,1,2) :  24
# Invalid Choice!
# Pick a position (0,1,2) :  35
# Invalid Choice!
# Pick a position (0,1,2) :  sadad
# Invalid Choice!
# Pick a position (0,1,2) :  2
# 2

# %%
def replacement_choice(gamelist,position):
    user_placement = input("Type a string to place at the position")

    game_list[position] = user_placement

    return game_list

# %%
replacement_choice(game_list,1)
# Out:
# Type a string to place at the position test
# [0, 'test', 2]

# %%
def gameon_choice():
    choice = 'wrong'

    while choice not in ['Y','N']:
        choice = input("Keep Playing ? (Y or N) :")

        if choice not in ['Y','N']:
            print("Please choose either Y or N")
    if choice == 'Y':
        return True
    else:
        return False

# %%
gameon_choice()
# Out:
# Keep Playing ? (Y or N) : h
# Please choose either Y or N
# Keep Playing ? (Y or N) : N
# False

# %%
game_on = True
game_list = [0,1,2]

while game_on:
    display_game(game_list)

    position = position_choice()

    game_list = replacement_choice(game_list,position)

    display_game(game_list)

    game_on = gameon_choice()
# Out:
# Here is the Current List :
# [0, 1, 2]
# Pick a position (0,1,2) :  1
# Type a string to place at the position 2
# Here is the Current List :
# [0, '2', 2]
# Keep Playing ? (Y or N) : y
# Please choose either Y or N
# Keep Playing ? (Y or N) : 1
# Please choose either Y or N
# Keep Playing ? (Y or N) : Y
# Here is the Current List :
# [0, '2', 2]
# Pick a position (0,1,2) :  1
# Type a string to place at the position My choice
# Here is the Current List :
# [0, 'My choice', 2]
# Keep Playing ? (Y or N) : N
